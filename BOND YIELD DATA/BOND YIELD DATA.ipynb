# %%
import pandas as pd
import requests 
import numpy as np
from pathlib import Path

# %%
Monthly_US_Treasury_Yield = Path('monthly_csv.csv')

Monthly_US_Treasury_Yield_DF = pd.read_csv(Monthly_US_Treasury_Yield, index_col = "Date", parse_dates=True, infer_datetime_format=True)

# %%
Monthly_US_Treasury_Yield_DF.head(10)
# Out:
#             Rate
# Date
# 1953-04-30  2.83
# 1953-05-31  3.05
# 1953-06-30  3.11
# 1953-07-31  2.93
# 1953-08-31  2.95
# 1953-09-30  2.87
# 1953-10-31  2.66
# 1953-11-30  2.68
# 1953-12-31  2.59
# 1954-01-31  2.48

# %%
date_range = Monthly_US_Treasury_Yield_DF[741:]

date_range.to_csv("Monthly US Treasury Yield 5 Years.csv")

# %%
date_range.plot(kind = 'line', legend = True, title = "Historic Monthly Change in US Treasury Bond Yield", figsize = (20,10))
