# %%
import requests
import pandas as pd
import numpy as np
import os
import csv
from pathlib import Path

from dotenv import load_dotenv


from alpha_vantage.timeseries import TimeSeries
import time

# %%
load_dotenv()
# Out:
# True

# %%
# Set Alpha_Vantage API key and RAPID API
alpha_api_key = os.getenv("ALPHAVANTAGE_API_KEY")
ts = TimeSeries(key='ALPHAVANTAGE_API_KEY')

# %%
type(alpha_api_key)
# Out:
# NoneType

# %%
alpha_api_key

# %%
response = requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=IBM&apikey=demo')
print(response.json())

# %%
base_url = 'https://www.alphavantage.co/query?'
function = 'TIME_SERIES_DAILY'
symbol = 'SI'

response = requests.get(f'{base_url}function={function}&symbol={symbol}&apikey={alpha_api_key}')
print(response.json())
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'SI', '3. Last Refreshed': '2020-12-18', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2020-12-18': {'1. open': '52.4100', '2. high': '52.8248', '3. low': '49.0000', '4. close': '51.1900', '5. volume': '1282736'}, '2020-12-17': {'1. open': '47.0500', '2. high': '53.7000', '3. low': '47.0000', '4. close': '52.9400', '5. volume': '1424148'}, '2020-12-16': {'1. open': '46.6600', '2. high': '46.6600', '3. low': '44.0000', '4. close': '45.4700', '5. volume': '659213'}, '2020-12-15': {'1. open': '41.0000', '2. high': '45.9999', '3. low': '40.5000', '4. close': '43.6000', '5. volume': '651376'}, '2020-12-14': {'1. open': '41.5600', '2. high': '43.9800', '3. low': '40.0000', '4. close': '40.5900', '5. volume': '1499140'}, '2020-12-11': {'1. open': '38.8400', '2. high': '40.5140', '3. low': '38.6300', '4. close': '39.4900', '5. volume': '217408'}, '2020-12-
# ...

# %%
response_dict = response.json()
_, header = response.json()

#Convert to pandas dataframe
silver_df = pd.DataFrame.from_dict(response_dict[header], orient='index')

# %%
silver_df
# Out:
#             1. open  2. high   3. low 4. close 5. volume
# 2020-12-18  52.4100  52.8248  49.0000  51.1900   1282736
# 2020-12-17  47.0500  53.7000  47.0000  52.9400   1424148
# 2020-12-16  46.6600  46.6600  44.0000  45.4700    659213
# 2020-12-15  41.0000  45.9999  40.5000  43.6000    651376
# 2020-12-14  41.5600  43.9800  40.0000  40.5900   1499140
# ...             ...      ...      ...      ...       ...
# 2020-08-05  14.0000  14.1900  13.8292  14.0900    218840
# 2020-08-04  14.0600  14.0700  13.5686  13.8100     65777
# 2020-08-03  14.0200  14.0774  13.8100  13.9500    109456
# 2020-07-31  14.1500  14.3200  13.6000  13.6700    365386
# 2020-07-30  14.1600  14.4200  14.1500  14.3400    133221
#
# [100 rows x 5 columns]

# %%
# Save the dataframe as a csv file
#gold_data.to_csv('gold_close_prices.csv', encoding='utf-8', index=True)
#silver_data.to_csv('silver_close_prices.csv', encoding='utf-8', index=True)

# %%
'https://financialmodelingprep.com/api/v3/historical-price-full/SI?apikey=bd7e834d9650fa43db0e2a0b3bed763e'
